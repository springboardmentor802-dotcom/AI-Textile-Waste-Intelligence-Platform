# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt

from torchvision import datasets, transforms, models
from torch.utils.data import Subset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay
)

# %%
DATASET_PATH = "../datasets/raw/biodegradable_fabrics"
MODEL_PATH = "../models/fabric_classifier.pth"

BATCH_SIZE = 32

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

print(device)
# Out:
# cpu

# %%
test_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485,0.456,0.406],
        std=[0.229,0.224,0.225]
    )
])

# %%
dataset = datasets.ImageFolder(
    DATASET_PATH,
    transform=test_transform
)

print(dataset.classes)
# Out:
# ['Abaca', 'Cotton', 'Hessian', 'Linen', 'Silk', 'Wool']

# %%
import os

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# c:\Users\devan\AI_textile_waste_management_system\ai_models\notebooks

# %%
import os

print(os.listdir("../datasets/raw"))
# Out:
# ['biodegradable_fabrics', 'fashion-mnist_test-selected-columns.csv', 'tfd']

# %%
indices = list(range(len(dataset)))
labels = [label for _, label in dataset.samples]

train_idx, temp_idx = train_test_split(
    indices,
    test_size=0.30,
    stratify=labels,
    random_state=42
)

temp_labels = [labels[i] for i in temp_idx]

val_idx, test_idx = train_test_split(
    temp_idx,
    test_size=0.50,
    stratify=temp_labels,
    random_state=42
)

test_dataset = Subset(
    dataset,
    test_idx
)

test_loader = DataLoader(
    test_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
model = models.efficientnet_b0(weights=None)

model.classifier[1] = torch.nn.Linear(
    model.classifier[1].in_features,
    len(dataset.classes)
)

model.load_state_dict(
    torch.load(
        MODEL_PATH,
        map_location=device
    )
)

model.to(device)

model.eval()

print("Model Loaded Successfully")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 8
#       4     model.classifier[1].in_features,
#       5     len(dataset.classes)
#       6 )
#       7
# ----> 8 model.load_state_dict(
#       9     torch.load(
#      10         MODEL_PATH,
#      11         map_location=device
#
# File c:\Users\devan\AI_textile_waste_management_system\ai_models\venv\Lib\site-packages\torch\nn\modules\module.py:2638, in Module.load_state_dict(self, state_dict, strict, assign)
#    2630         error_msgs.insert(
#    2631             0,
#    2632             "Missing key(s) in state_dict: {}. ".format(
#    2633                 ", ".join(f'"{k}"' for k in missing_keys)
#    2634             ),
#    2635         )
#    2637 if len(error_msgs) > 0:
# -> 2638     raise RuntimeError(
#    2639         "Error(s) in loading state_dict for {}:\n\t{}".format(
#    2640             self.__class__.__name__, "\n\t".join(error_msgs)
#    2641         )
#    2642     )
#    2643 return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for EfficientNet:
# 	Missing key(s) in state_dict: "classifier.1.weight", "classifier.1.bias".
# 	Unexpected key(s) in state_dict: "classifier.1.1.weight", "classifier.1.1.bias".
